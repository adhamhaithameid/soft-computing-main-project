# %% [markdown]
# # Epileptic Seizure Recognition - Full Soft Computing Pipeline
#
# This notebook runs the full project workflow (data fetch, preprocessing, feature reduction/selection, modeling, and results generation).

# %%
# !python ../../04_src/fetch_data.py

# %%
# !python ../../04_src/run_experiments.py

# %%
# !python ../../04_src/generate_paper_drafts.py
